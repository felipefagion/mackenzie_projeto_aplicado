# %% [markdown]
# <!DOCTYPE html>
# <html lang="pt-BR">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Análise de Dados no Mercado Imobiliário</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 20px;
#             background-color: #f0f0f0;
#         }
#         h1 {
#             text-align: center;
#             font-size: 2.5em;
#             margin-bottom: 20px;
#         }
#         h2 {
#             margin-top: 40px;
#         }
#         ul {
#             list-style-type: none;
#             padding: 0;
#         }
#         li {
#             margin: 10px 0;
#         }
#         a {
#             text-decoration: none;
#             color: #007BFF;
#         }
#         a:hover {
#             text-decoration: underline;
#         }
#     </style>
# </head>
# <body>
#     <h1>Análise de Dados no Mercado Imobiliário 🏙️ </h1>
#     <ul>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="pt-BR">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 20px;
#             background-color: #f0f0f0;
#         }
#         h1 {
#             text-align: left;
#             font-size: 2em;
#             margin-bottom: 20px;
#         }
#         h2 {
#             margin-top: 40px;
#         }
#         ul {
#             list-style-type: none;
#             padding: 0;
#         }
#         li {
#             margin: 10px 0;
#         }
#         a {
#             text-decoration: none;
#             color: #007BFF;
#         }
#         a:hover {
#             text-decoration: underline;
#         }
#         .bibliotecas {
#             margin-left: 20px;
#         }
#         .bibliotecas li {
#             position: relative;
#             padding-left: 15px;
#         }
#         .bibliotecas li::before {
#             content: '•';
#             position: absolute;
#             left: 0;
#             color: #007BFF;
#             font-size: 1.2em;
#         }
#     </style>
# </head>
# <body>
#     <h1>Sumário</h1>
#     <ul>
#         <li><a href="#apresentacao-empresa">1. Apresentação da Empresa</a></li>
#         <li><a href="#descricao-dataset">2. Descrição do Dataset</a></li>
#         <li><a href="#objetivo-do-estudo">3. Objetivo do Estudo</a></li>
#         <li><a href="#metadados">4. Apresentação dos Metadados</a></li>
#         <li><a href="#importacao-bibliotecas">5. Importação de Bibliotecas Python</a>
#             <ul class="bibliotecas">
#                 <li>NumPy: Para manipulação de arrays e cálculos numéricos.</li>
#                 <li>Pandas: Para manipulação e análise de dados.</li>
#                 <li>Matplotlib: Para visualização de dados.</li>
#                 <li>Seaborn: Para visualizações estatísticas.</li>
#             </ul>
#         </li>
#         <li><a href="#preprocessamento">6. Pré-processamento dos Dados</a></li>
#         <li><a href="#analise-descritiva">7. Análise Descritiva</a></li>
#         <li><a href="#exploracao-de-variaveis">8. Exploração de Variáveis</a></li>
#         <li><a href="#analise-de-correlacao">9. Análise de Correlação</a></li>
#         <li><a href="#conclusoes">12. Conclusões e Próximos Passos</a></li>
#         <li><a href="#referencias">13. Referências</a></li>
#     </ul>

# %% [markdown]
# <h2 id="apresentacao-empresa">1. Apresentação da Empresa</h2>
#     <p>Conteúdo sobre a apresentação da empresa...</p>

# %% [markdown]
# <h2 id="descricao-dataset">2. Descrição do Dataset</h2>
#     <p>Conteúdo sobre a descrição do dataset...</p>

# %% [markdown]
# <h2 id="objetivo-do-estudo">3. Objetivo do Estudo</h2>
#     <p>Conteúdo sobre o objetivo do estudo...</p>

# %% [markdown]
#    <h2 id="metadados">4. Apresentação dos Metadados</h2>
#     <p>Conteúdo sobre os metadados...</p>

# %% [markdown]
# <h2 id="importacao-bibliotecas">5. Importação de Bibliotecas Python</h2>

# %%
#Manipulação de dados
import numpy as np
import pandas as pd

#Visualização de Dados
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('base_imoveis.xlsx')

# %%
df.head()
# Out:
#     id  valor_total     unit  area_util  quartos  vagas  condominio  suites  \
# 0  526       189900  5934.38         32        2      1       180.0       0
# 1  734       221110  5142.09         43        2      1       250.0       0
# 2  738       219990  5116.05         43        1      1       300.0       0
# 3  753       219990  5116.05         43        2      1       300.0       0
# 4  924       220000  5365.85         41        2      1       300.0       0
#
#    banheiros  piscina  ...  qtd_dados_bairro  media_idh media_gini  \
# 0          1        0  ...              36.0   0.697182   0.410909
# 1          1        0  ...              36.0   0.697182   0.410909
# 2          1        1  ...              36.0   0.697182   0.410909
# 3          1        1  ...              36.0   0.697182   0.410909
# 4          1        1  ...              36.0   0.697182   0.410909
#
#   expectativa_vida renda_percapita          estacao_prox  linha_prox  \
# ...

# %%
df.shape
# Out:
# (2499, 26)

# %%
df.columns
# Out:
# Index(['id', 'valor_total', 'unit', 'area_util', 'quartos', 'vagas',
#        'condominio', 'suites', 'banheiros', 'piscina', 'academia', 'quadra',
#        'endereco', 'link', 'bairro', 'media_bairro', 'qtd_dados_bairro',
#        'media_idh', 'media_gini', 'expectativa_vida', 'renda_percapita',
#        'estacao_prox', 'linha_prox', 'dist', 'lat', 'lon'],
#       dtype='object')

# %%
df.nunique()
# Out:
# id                  2499
# valor_total          788
# unit                1787
# area_util            189
# quartos                5
# vagas                  8
# condominio           531
# suites                 5
# banheiros              8
# piscina                2
# academia               2
# quadra                 2
# endereco            1778
# link                2498
# bairro                89
# media_bairro          87
# qtd_dados_bairro      34
# media_idh             88
# media_gini            86
# expectativa_vida      89
# renda_percapita       89
# estacao_prox          79
# linha_prox             6
# dist                1729
# lat                 1729
# lon                 1729
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2499 non-null   int64
#  1   valor_total       2499 non-null   int64
#  2   unit              2499 non-null   float64
#  3   area_util         2499 non-null   int64
#  4   quartos           2499 non-null   int64
#  5   vagas             2499 non-null   int64
#  6   condominio        2264 non-null   float64
#  7   suites            2499 non-null   int64
#  8   banheiros         2499 non-null   int64
#  9   piscina           2499 non-null   int64
#  10  academia          2499 non-null   int64
#  11  quadra            2499 non-null   int64
#  12  endereco          2499 non-null   object
#  13  link              2499 non-null   object
#  14  bairro            2499 non-null   object
#  15  media_bairro      2492 non-null   float64
# ...

# %%
df.describe().round(2)
# Out:
#             id  valor_total      unit  area_util  quartos    vagas  \
# count  2499.00      2499.00   2499.00    2499.00  2499.00  2499.00
# mean   1290.48    548085.20   7144.40      71.32     2.28     1.23
# std     740.95    554448.72   2885.56      44.76     0.63     1.08
# min       1.00     80000.00   1068.18      22.00     1.00     0.00
# 25%     649.50    265000.00   5087.72      49.00     2.00     1.00
# 50%    1292.00    380000.00   6491.23      60.00     2.00     1.00
# 75%    1932.50    598500.00   8487.71      74.00     3.00     1.00
# max    2570.00  12000000.00  18750.00     640.00     5.00    39.00
#
#        condominio   suites  banheiros  piscina  ...   quadra  media_bairro  \
# count     2264.00  2499.00    2499.00  2499.00  ...  2499.00       2492.00
# mean      1720.33     0.65       1.74     0.37  ...     0.31       7051.06
# std      28048.55     0.81       1.02     0.48  ...     0.46       2090.46
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# valor_total           0
# unit                  0
# area_util             0
# quartos               0
# vagas                 0
# condominio          235
# suites                0
# banheiros             0
# piscina               0
# academia              0
# quadra                0
# endereco              0
# link                  0
# bairro                0
# media_bairro          7
# qtd_dados_bairro      7
# media_idh             0
# media_gini            0
# expectativa_vida      0
# renda_percapita       0
# estacao_prox          0
# linha_prox            0
# dist                  0
# lat                   0
# lon                   0
# dtype: int64

# %%
df.hist(column=['valor_total', 'renda_percapita'],figsize=(18,6), grid=False)

# Show the plot
plt.show()

# %% [markdown]
# <h2 id="preprocessamento">6. Pré-processamento dos Dados</h2>
#     <p>Conteúdo sobre o pré-processamento dos dados...</p>

# %% [markdown]
# <h2 id="analise-descritiva">7. Análise Descritiva</h2>
#     <p>Conteúdo sobre a análise descritiva...</p>

# %% [markdown]
# <h2 id="exploracao-de-variaveis">8. Exploração de Variáveis</h2>
#     <p>Conteúdo sobre a exploração de variáveis...</p>

# %% [markdown]
# <h2 id="analise-de-correlacao">9. Análise de Correlação</h2>
#     <p>Conteúdo sobre a análise de correlação...</p>

# %% [markdown]
#  <h2 id="conclusoes">12. Conclusões e Próximos Passos</h2>
#     <p>Conteúdo sobre as conclusões e próximos passos...</p>

# %% [markdown]
# <h2 id="referencias">13. Referências</h2>
#     <p>Conteúdo sobre as referências...</p>
